# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Compute Pareto frontier (maximize both recall and QPS)


def compute_pareto_frontier(dataframe: pd.DataFrame, recall_col: str = "recall", qps_col: str = "QPS") -> pd.DataFrame:
    values = dataframe[[recall_col, qps_col]].to_numpy()
    is_pareto = []
    for i, (r_i, q_i) in enumerate(values):
        dominating = (values[:, 0] >= r_i) & (values[:, 1] >= q_i) & (
            (values[:, 0] > r_i) | (values[:, 1] > q_i))
        is_pareto.append(not np.any(dominating))
    pareto_df = dataframe[np.array(is_pareto)].copy()
    # Sort for a nice trace from low->high QPS (recall should be non-decreasing along the frontier)
    pareto_df.sort_values(by=[qps_col, recall_col], ascending=[
                          True, False], inplace=True)
    return pareto_df

# %%
import h5py


def read_hdf5_dataset(filepath, keys):
    with h5py.File(filepath, "r") as f:
        ret = []
        for k in keys:
            ret.append(f[k][:])
    return ret


(
    base,
    base_scalars,
    test,
    test_ranges,
    test_hybrid_knn,
) = read_hdf5_dataset(
    "/data/anas.aitaomar/foodvec_v2/unify_store/foodvec_v2_with_scalar.hdf5",
    ["base", "base_scalars", "test", "test_ranges", "test_hybrid_knn"],
)

# %%
base.shape, base_scalars.shape, test.shape, test_ranges.shape, test_hybrid_knn.shape
# Out:
# ((1000000, 128), (1000000,), (1000, 128), (1000, 2), (1000, 100))

# %%
max_base_scalar = max(base_scalars)
min([float((_range[1] - _range[0]) / max_base_scalar)
    for _range in test_ranges]), max([float((_range[1] - _range[0]) / max_base_scalar)
                                      for _range in test_ranges])
# Out:
# (0.010776010776010776, 0.4998144998144998)

# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, FuncFormatter, PercentFormatter
from cycler import cycler


def _human_num(x: float) -> str:
    if x is None or not np.isfinite(x):
        return ""
    ax = abs(x)
    if ax >= 1e9:
        s = f"{x/1e9:.1f}B"
    elif ax >= 1e6:
        s = f"{x/1e6:.1f}M"
    elif ax >= 1e3:
        s = f"{x/1e3:.1f}k"
    elif ax >= 1:
        s = f"{x:.0f}"
    else:
        s = f"{x:.2g}"
    return s.rstrip("0").rstrip(".")


def _auto_log_subs(ymin: float, ymax: float):
    ymin = max(ymin, np.nextafter(0, 1))
    lo = math.log10(ymin)
    hi = math.log10(ymax)
    decades = max(1, int(math.floor(hi) - math.ceil(lo) + 1))
    if decades >= 5:
        return [2, 5]
    if decades >= 3:
        return [2, 3, 5]
    return [2, 3, 5, 7]


def _compose_label(row, label_cols, fallback_name: str) -> str:
    parts = []
    for col in label_cols:
        if col in row and row[col] is not None and np.isfinite(row[col]) if isinstance(row[col], (int, float, np.floating)) else True:
            val = row[col]
            if isinstance(val, (int, np.integer)):
                parts.append(f"{col}={int(val)}")
            elif isinstance(val, (float, np.floating)):
                # show as int if whole-number, else compact float
                parts.append(
                    f"{col}={int(val) if float(val).is_integer() else f'{val:g}'}")
            else:
                parts.append(f"{col}={val}")
    return ", ".join(parts) if parts else fallback_name


def plot_multi_pareto(
    name_to_df: dict,
    recall_col: str = "recall",
    qps_col: str = "QPS",
    annotate: bool = False,
    label_cols: tuple[str, ...] = ("ef",),   # <— label with ef by default
    title: str = "Recall–QPS Pareto Frontiers",
) -> None:
    mpl.rcParams.update({
        "figure.dpi": 160,
        "savefig.dpi": 300,
        "axes.spines.top": False,
        "axes.spines.right": False,
        "axes.grid": True,
        "grid.linestyle": "--",
        "grid.alpha": 0.3,
        "axes.titlesize": 13,
        "axes.labelsize": 11,
        "legend.fontsize": 9,
        "xtick.labelsize": 10,
        "ytick.labelsize": 10,
        "axes.prop_cycle": cycler(color=plt.cm.tab10.colors),
    })

    fig, ax = plt.subplots(figsize=(9, 6), constrained_layout=True)
    ax.set_axisbelow(True)

    # Collect global y-range (for dynamic log ticks)
    all_y = []
    for df in name_to_df.values():
        if qps_col in df.columns:
            vals = np.asarray(df[qps_col])
            all_y.append(vals[np.isfinite(vals)])
    all_y = np.concatenate(all_y) if all_y else np.array([1.0])
    all_y = all_y[all_y > 0]  # log-safe

    for name, df_i in name_to_df.items():
        pareto_i = compute_pareto_frontier(
            df_i, recall_col=recall_col, qps_col=qps_col)
        if pareto_i.empty:
            continue

        pareto_i = pareto_i.sort_values(
            by=[qps_col, recall_col], ascending=[True, False]).copy()
        pareto_i = pareto_i[np.isfinite(pareto_i[qps_col])]
        pareto_i = pareto_i[pareto_i[qps_col] > 0]
        if pareto_i.empty:
            continue

        ax.plot(
            pareto_i[recall_col],
            pareto_i[qps_col],
            marker="o",
            markersize=4,
            linewidth=1.8,
            label=name,
        )

        if annotate:
            for _, row in pareto_i.iterrows():
                label = _compose_label(row, label_cols, fallback_name=name)
                ax.annotate(
                    label,
                    (row[recall_col], row[qps_col]),
                    textcoords="offset points",
                    xytext=(6, 6),
                    fontsize=3,
                    alpha=0.9,
                )

    # X axis: recall as %
    ax.set_xlabel("Recall (higher is better)")
    ax.set_xlim(0, 1.0)
    ax.xaxis.set_major_formatter(PercentFormatter(xmax=1.0))
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=12))

    # Y axis: log QPS with human-readable ticks
    ax.set_ylabel("QPS (log scale, higher is better)")
    ax.set_yscale("log")

    if all_y.size > 0:
        ymin = float(np.nanmax([np.nanmin(all_y), 1e-12]))
        ymax = float(np.nanmax(all_y))
        lo_decade = 10 ** math.floor(math.log10(ymin))
        hi_decade = 10 ** math.ceil(math.log10(ymax))
        ax.set_ylim(lo_decade, hi_decade)

        subs = _auto_log_subs(ymin, ymax)
        ax.yaxis.set_major_locator(LogLocator(base=10, numticks=12))
        ax.yaxis.set_minor_locator(LogLocator(base=10, subs=subs, numticks=12))

    ax.yaxis.set_major_formatter(FuncFormatter(lambda y, pos: _human_num(y)))
    # Only label minor ticks when density is light
    if len(_auto_log_subs(*ax.get_ylim())) <= 3:
        ax.yaxis.set_minor_formatter(
            FuncFormatter(lambda y, pos: _human_num(y)))
    else:
        ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())

    ax.grid(which="major", linewidth=0.8, alpha=0.6)
    ax.grid(which="minor", linewidth=0.5, alpha=0.25)

    ax.legend(title="Experiment", loc="center left",
              bbox_to_anchor=(1.02, 0.5), frameon=False)
    ax.set_title(title)
    plt.show()


# exps = {
#     # "unify-sorted-scalar": pd.read_csv("/data/anas.aitaomar/sift/.cache/results-unify-sorted-scalar.csv"),
#     # "unify-uniform-scalar": pd.read_csv("/data/anas.aitaomar/sift/.cache/results-unify-uniform-scalar.csv"),
#     "unify-uniform-scalar-1-50": pd.read_csv("/data/anas.aitaomar/sift/.cache/results-unify-uniform-scalar-s-1-50.csv"),
#     # "rwalks-range": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500.csv"),
#     # "rwalks-pron-var": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_pron_var.csv"),
#     # "rwalks-max-pron": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron.csv"),
#     # "rwalks-320": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk3_20.csv"),
#     "rwalks-320-prefetch": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk320_sift_final.csv"),
#     "rwalks-415": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk415_sift.csv"),
#     "rwalks-320": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk320_sift.csv"),
#     # "rwalks-max-pron-M-32": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500_bucketing_binary_max_pron_M_32.csv"),
#     # "rwalks-range-pf--10.0": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_-10.0_efc_500.csv"),
#     # "rwalks-range-bucketing-naive": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_naive_pf_0.0_efc_500_bucketing_naive.csv"),
# }

exps = {

    # "unify-uniform-scalar-1-50": pd.read_csv("/data/anas.aitaomar/foodvec_v2/.cache/results-unify-sorted-scalar.csv"),
    # "rwalks-320-prefetch": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk320_foodvec_v2_final.csv"),
    # "rwalks-320-prefetch-ef2k": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_200_bucketing_binary_max_pron_M_16_walk320_foodvec_v2_ef2k.csv"),
    # "rwalks-range": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500_bucketing_binary_max_pron_M_16_sift50M.csv"),
    # "unify": pd.read_csv("/data/anas.aitaomar/sift/.cache/results-unify-50m.csv"),

    "unify": pd.read_csv("/data/anas.aitaomar/sift/.cache/results-unify-1m-multithread.csv"),
    "rwalks-range": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500_bucketing_binary_max_pron_M_16_sift-128-euclidean_multithread.csv"),
    "rwalks-range-M32": pd.read_csv("/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500_bucketing_binary_max_pron_M_32_sift-128-euclidean_multithread.csv")

}


plot_multi_pareto(exps, annotate=False, label_cols=("ef", "al"))

# %%
df = pd.read_csv(
    "/data/anas.aitaomar/sift/.cache/results-unify-1m-multithread.csv")
df[df["recall"] >= 0.99].sort_values(by="QPS", ascending=False)
# Out:
#        ef  al  recall  latency(ms)           QPS
# 8      50  32  0.9932     0.029844  33507.253787
# 16    110  16  0.9902     0.030767  32502.646364
# 11     70  32  0.9969     0.034462  29017.489484
# 22    150  16  0.9943     0.038992  25646.490525
# 19    130  16  0.9928     0.040032  24980.220958
# ..    ...  ..     ...          ...           ...
# 290  1930  32  0.9995     0.344364   2903.902607
# 287  1910  32  0.9996     0.346752   2883.902130
# 284  1890  32  0.9995     0.350281   2854.850819
# 293  1950  32  0.9995     0.352988   2832.953630
# 299  1990  32  0.9998     0.365324   2737.292483
#
# [232 rows x 5 columns]

# %%
df = pd.read_csv(
    "/home/anas.aitaomar/rwalks-reproduce-v2/.cache/range_exp_binary_pf_0.0_efc_500_bucketing_binary_max_pron_M_16_sift-128-euclidean_multithread.csv")
df[df["recall"] >= 0.99].sort_values(by="QPS", ascending=False)
# Out:
#        ef     al  recall  latency(ms)           QPS
# 146   330   0.00  0.9901    55.288076  18087.082516
# 155   350   0.00  0.9918    60.064316  16648.820298
# 165   370   0.01  0.9910    62.364817  16034.681948
# 174   390   0.01  0.9914    62.503099  15999.206582
# 173   390   0.00  0.9932    62.584639  15978.361822
# ..    ...    ...     ...          ...           ...
# 891  1990 -10.00  0.9994   250.423431   3993.236553
# 847  1890  -0.01  0.9998   250.556469   3991.116271
# 884  1970   0.00  0.9993   250.936031   3985.079363
# 867  1930   0.01  0.9994   251.212358   3980.695878
# 885  1970   0.01  0.9993   251.477003   3976.506749
#
# [469 rows x 5 columns]
